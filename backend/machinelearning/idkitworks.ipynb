# %%
import pandas as pd
import numpy as np 
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %%
data = pd.read_csv("Data.csv")

# %%
X = data[['SEM-I', 'SEM-II','SEM-III','SEM-IV']]
y = data['SEM-V']

# %%
x_train,x_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y, test_size = 0.3 , random_state = 2)

# %%
linear = linear_model.LinearRegression()

# %%
linear.fit(x_test, y_test)
# Out:
# LinearRegression()

# %%
linear.score(x_test, y_test)
# Out:
# 0.552789250491259

# %%
input = ((5.9,7.36,6.39,6.5))#7.89,8.5,8.02,8.14
                            #7.94,7.76,7.45,8.82

input_array = np.asarray(input)

input_array_reshape = input_array.reshape(1, -1)

predictions = linear.predict(input_array_reshape)

print("predictions are: ", predictions[0])
# Out:
# predictions are:  7.051467987014112
# C:\Users\Noyal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(x_train)

linear = LinearRegression()
linear.fit(X_train_poly, y_train)  

score = linear.score(X_test_poly, y_test)
print(f"Degree {3}: R² Score = {score:.4f}")


input_array = np.asarray(input)  
input_array_reshape = input_array.reshape(1, -1)  

input_array_poly = poly.transform(input_array_reshape)  

predictions = linear.predict(input_array_poly)

print("Predictions are:", predictions[0])
# Out:
# Degree 3: R² Score = 0.5535
# Predictions are: 8.133682908221807
# C:\Users\Noyal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
train_data=x_train.join(y_train)
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'SEM-I'}>,
#         <Axes: title={'center': 'SEM-II'}>],
#        [<Axes: title={'center': 'SEM-III'}>,
#         <Axes: title={'center': 'SEM-IV'}>],
#        [<Axes: title={'center': 'SEM-V'}>, <Axes: >]], dtype=object)

# %%
import seaborn as sns
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >
